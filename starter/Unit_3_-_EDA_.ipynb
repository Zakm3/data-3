# %% [markdown]
# # Unit 3 Project - Exploratory Data Analysis

# %% [markdown]
# ## Part 1 - Univariate Analysis - Visualization

# %% [markdown]
# ### Step 1 - Open Jupyter Notebook in New Virtual Environment

# %% [markdown]
# ###### This step should have been completed prior to opening the Jupyter Notebook. If it was not, create and activate your virtual environment, then restart your notebook within the venv.

# %% [markdown]
# ### Step 2 - Load DataFrame and Explore Dataset

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %%
# import pandas and numpy
import pandas as pd
import numpy as np

# %%
# load salary.csv into dataframe
df = pd.read_csv('salary.csv')

# %%
# look at first few values of dataframeabs
df.head(100)
# Out:
#     age  gender    education  industry  industry_experience       salary
# 0    19    Male  high school  business                    0  33640.60752
# 1    21    Male  high school  business                    2  43554.24216
# 2    19    Male  high school  business                    0  39795.29424
# 3    22    Male  high school  business                    1  51102.98856
# 4    21    Male  high school  business                    1  32809.57056
# ..  ...     ...          ...       ...                  ...          ...
# 95   20  Female  high school  business                    1  44959.44960
# 96   19  Female  high school  business                    1  40384.88064
# 97   18  Female  high school  business                    1  48588.73344
# 98   19  Female  high school  business                    0  45403.33824
# 99   18  Female  high school  business                    1  33463.27296
#
# [100 rows x 6 columns]

# %%
# look at basic dataframe info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25439 entries, 0 to 25438
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  25439 non-null  int64
#  1   gender               25439 non-null  object
#  2   education            25439 non-null  object
#  3   industry             25439 non-null  object
#  4   industry_experience  25439 non-null  int64
#  5   salary               25439 non-null  float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 1.2+ MB

# %% [markdown]
# ### Step 3 - Review Types of Basic Univariate Plots

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# #### Fill in blanks with a brief description of each plot type:
#
#
# - Histogram
# > A histogram is a chart that groups numeric data into bins, displaying the bins as segmented columns.
# - Density Plot / KDE
# > KDE Plot described as Kernel Density Estimate is used for visualizing the Probability Density of a continuous variable.
# - Bar Chart
# > Bar charts are one of the many techniques used to present data in a visual form so that the reader may readily recognize patterns or trends. Bar charts usually present categorical variables, discrete variables or continuous variables grouped in class intervals.
# - Line Plot
# > a line plot is a graph that uses lines to connect individual data points
# - Univariate scatter plot
# > Plots different observations/values of the same variable corresponding to the index/observation number.
# - Violin Plot
# > A violin plot depicts distributions of numeric data for one or more groups using density curves.
# - Box Plot
# > A box plot is a graphical rendition of statistical data based on the minimum, first quartile, median, third quartile, and maximum. The term "box plot" comes from the fact that the graph looks like a rectangle with lines extending from the top and bottom.
# - Pie Chart
# > A pie chart  is a circular statistical graphic, which is divided into slices to illustrate numerical proportion
# - Rug Plot
# > A Rug Plot would be another way to display a distribution as an adjunct to your primary plot.  A Rug Plot is simply a projection of raw data points onto a particular axis, without involving the binning process of a histogram.

# %% [markdown]
# ### Step 4 - Choose Which Plot(s) You Will Use for Each Variable

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# #### Take a moment to plan what types of plots you will make for each variable
#
#
# - age
# > histogram
# - gender
# > bar chart
# - education
# > pie chart
# - industry
# > pie chart
# - industry experience
# > bar chart
# - salary
# > violin plot

# %% [markdown]
# ### Step 5 - Create Plots for Each Variable in Dataset

# %%
# import seaborn
import seaborn as sns


# set standard plot type as seaborn plot
sns.set()


# import matplotlib
import matplotlib.pyplot as plt


# write command for plots to appear in jupyter cells automatically

# %matplotlib inline

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# ### Plot for 'age' column

# %%
# create plot for age column
# sets figure size
plt.figure(figsize=(14,7))

# establishes figure with data and plot type
ax = sns.histplot(data=df, x='age', palette="magma",  bins=8)

# sets x and y labels
plt.xlabel("Age", fontsize=20)
plt.ylabel("Number of Managers", fontsize=14)

# sets title
plt.title("Manager Ages in Survey", fontsize=15);

# %% [markdown]
# ##### Insights:
#
# We don't have as many young managers as we do old ones.

# %% [markdown]
# ### Plot for 'industry' column

# %%
# create plot for industry column
plt.figure(figsize=(10,10))

data = df['industry'].value_counts()

labels = ["Healthcare", "Technology", "Finance", "Business"]

colors = sns.color_palette('husl')

plt.title("Percent of Managers in each Industry", fontsize=16)

ax = plt.pie(data, colors = colors, labels = labels, autopct = '%.0f%%');

# %% [markdown]
# ##### Insights:
#
# An equal amount of managers in all gathered industry fields.

# %% [markdown]
# ### Plot for 'salary' column

# %%
# create plot for salary column
plt.figure(figsize=(14,7))

sns.violinplot(x=df['salary'], color = 'skyblue')

plt.xlabel("Salary", fontsize=14)
plt.title("Density of Manager Salaries");

# %% [markdown]
# ##### Insights:
#
# Most of the manager salaries are in the 100,000 range

# %% [markdown]
# ### Plot for 'industry_experience' column

# %%
# create plot for industry experience column
plt.figure(figsize=(12,6))

ax = sns.countplot(data=df, x='industry_experience',palette="rocket")

plt.xticks(rotation=90)
plt.xlabel("Industry experience", fontsize=13)
plt.ylabel("Number of Managers", fontsize=13)
plt.title("Industry Experience of Managers", fontsize=15);

# %% [markdown]
# ##### Insights:
#
# Most of the Managers that took the survey have industry experince of 15-25 yesrs.

# %% [markdown]
# ### Plot for 'education' column

# %%
plt.figure(figsize=(10,10))

data = df['education'].value_counts()

labels = ["bachelor's degree", "master's degree", "some college", "high school"]

colors = sns.color_palette('crest')

plt.title("Manager's Education Levels", fontsize=16)

ax = plt.pie(data, colors = colors, labels = labels, autopct = '%.0f%%');

# %% [markdown]
# ##### Insights:
#
# Most managers have a Bachelors or Master's degree

# %% [markdown]
# ### Plot for 'gender' column

# %%
# create plot for gender column
plt.figure(figsize=(12,6))

ax = sns.countplot(data=df, x='gender',palette="icefire")

plt.xticks(rotation=90)
plt.xlabel("Gender", fontsize=13)
plt.ylabel("Number of Each Gender in Industry", fontsize=13)
plt.title("Gender of managers in Survey", fontsize=15);

# %% [markdown]
# ##### Insights:
#
# An equal amount of Male and Female managers took the survey.

# %% [markdown]
# ## Part 2 - Summary Statistics

# %% [markdown]
# ### Step 1 - Review Summary Statistics

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# - mean
# > The mean is the average of a data set.
# - median
# > the median is the value separating the higher half from the lower half of a data sample
# - mode
# > The mode is the value that appears most often in a set of data
# - central tendency
# > A measure of central tendency is a single value that attempts to describe a set of data by identifying the central position within that set of data
# - distribution
# > A statistical distribution, or probability distribution, describes how values are distributed for a field. In other words, the statistical distribution shows which values are common and uncommon
# - variance
# > The term variance refers to a statistical measurement of the spread between numbers in a data set
# - standard deviation
#
# > Standard deviation is a statistic that measures the dispersion of a dataset relative to its mean and is calculated as the square root of the variance. The standard deviation is calculated as the square root of variance by determining each data point's deviation relative to the mean.

# %% [markdown]
# ### Step 2 - Find  & Report Summary Statistics For Numeric Variables

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# #### Age Summary Statistics

# %%
# use .describe to get summary statistics for age column
df['age'].describe()
# Out:
# count    25439.000000
# mean        46.219466
# std         12.758662
# min         18.000000
# 25%         36.000000
# 50%         47.000000
# 75%         57.000000
# max         67.000000
# Name: age, dtype: float64

# %%
# create boxplot to visualize age summary statistics
plt.figure(figsize=(12,4))

plt.title("Age Distribution for Managers", fontsize=16)

sns.boxplot(x=df['age'], color = 'pink')

plt.xlabel("Manager Age", fontsize=14);

# %% [markdown]
# - age **mean**
# > The mean age is 46.2
# - age **median**
# > The median age is 47
# - age **minimum**
# > The minimum age is 18
# - age **maximum**
# > The maximum age is 67
# - age **standard deviation**
# > The standard deviation is 12.8

# %% [markdown]
# ###### Reflection: How did mean and median differ above? Why do you think that is?
#
# the mean is 46.2 and the median is 47, The mean is an average of all the numbers whereas the median is just the middle value in a dataset.

# %% [markdown]
# #### Salary Summary Statistics

# %%
# use .describe to get summary statistics for salary
df['salary'].describe()
# Out:
# count     25439.000000
# mean     101416.000070
# std       26136.687123
# min       28054.080000
# 25%       84621.294048
# 50%      101148.480000
# 75%      119828.075728
# max      175223.321900
# Name: salary, dtype: float64

# %%
# create boxplot to visualize salary summary statistics
plt.figure(figsize=(12,6))

plt.title("Distribution of Salary Among Managers", fontsize=16)

sns.boxplot(x=df['salary'], color = "hotpink")

plt.xlabel("Annual Salary (USD)", fontsize=14);

# %% [markdown]
# - Salary **mean**
# > The mean salary is 101,416
# - Salary **median**
# > The median salary is 101,148.5
# - Salary **minimum**
# > The minimum salary is 28,054.1
# - Salary **maximum**
# > The maximum salary is 175,223.3
# - Salary **standard deviation**
# > The standard deviation is 26,136.7

# %% [markdown]
# ###### Reflection: How did mean and median differ above? Why do you think that is?
#
# They differed by about 300 and it's because the mean is an average of all the numbers whereas the median is just the middle value in a dataset.

# %% [markdown]
# ### Step 3 - Find Salary Summary Statistics By Industry

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %%
# use groupby() and describe() to get salary summary statistics by industry
df['salary'].groupby(df['industry']).describe()
# Out:
#              count           mean           std          min           25%  \
# industry
# business    6367.0   98296.471387  24822.138864  29340.67968  82482.816000
# finance     6383.0  102838.541755  26344.729075  30747.52224  86224.406400
# healthcare  6307.0   94767.547447  23696.008298  28054.08000  79538.185000
# technology  6382.0  109675.753478  27127.404233  32704.34400  92223.969112
#
#                      50%            75%           max
# industry
# business     98200.01048  116110.250464  159030.78048
# finance     102692.33568  122237.832000  166370.21852
# healthcare   94728.96000  112058.784000  152775.98600
# technology  109130.17575  129758.177182  175223.32190

# %%
# create visualization with multiple boxplots to show salary summary statistics by industry
plt.figure(figsize=(12,8))

ax = sns.boxplot(data=df, palette = 'mako', x='industry', y='salary')

plt.xlabel("Industry", fontsize=14)
plt.ylabel("Salary", fontsize=14)
plt.title("Distribution of Salaries Across Industries", fontsize=16);

# %% [markdown]
# ##### Insights:
#
# Tech is the leading industry with salaries.

# %% [markdown]
# ### Step 4 - Find Salary Summary Statistics By Education

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %%
# use groupby() and describe() to get salary summary statistics by education level
df['salary'].groupby(df['education']).describe()
# Out:
#                     count           mean           std        min  \
# education
# bachelors degree  10972.0  100710.905311  20960.707146  40962.240
# high school         781.0   47602.924607  10556.975508  28054.080
# masters degree     8979.0  115583.500303  21594.533546  68037.024
# some college       4707.0   84962.702227  24994.963474  29030.208
#
#                            25%            50%           75%           max
# education
# bachelors degree  85154.097000   98829.004800  115799.14680  159790.23450
# high school       39832.128000   46255.446000   53930.62080   78486.86520
# masters degree    98782.553760  113936.908800  131988.10416  175223.32190
# some college      68385.261696   84824.902426  103041.44640  149241.93034

# %%
# create visualization with multiple boxplots to show salary summary statistics by education level
plt.figure(figsize=(12,8))

ax = sns.boxplot(data=df, palette = 'magma', x='education', y='salary')

plt.xlabel("Education", fontsize=14)
plt.ylabel("Salary", fontsize=14)
plt.title("Salary Distribution By Education Level", fontsize=16);

# %% [markdown]
# ##### Insights:
# The higher the education level the higher the salary.

# %% [markdown]
# ### Step 5 - Find Salary Summary Statistics by Gender

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %%
# use groupby() and describe() to get salary summary statistics by gender
df['salary'].groupby(df['gender']).describe()
# Out:
#           count           mean           std        min         25%  \
# gender
# Female  12730.0   98209.928810  24978.233860  28054.080  81938.1888
# Male    12709.0  104627.368954  26867.859585  29725.182  87625.1900
#
#                 50%          75%          max
# gender
# Female   98057.3880  115867.1844  163708.4064
# Male    104240.0788  123838.3008  175223.3219

# %%
# create visualization with multiple boxplots to show summary statistics by gender
plt.figure(figsize=(12,8))

ax = sns.boxplot(data=df, palette = 'flare', x='gender', y='salary')

plt.xlabel("Gender", fontsize=14)
plt.ylabel("Salary", fontsize=14)
plt.title("Distribution of Salary By Gender", fontsize=16);

# %% [markdown]
# ##### Insights:
#
# Men get paid a higher salary than women.

# %% [markdown]
# ## Part 3 - Looking for Relationships in Data

# %% [markdown]
# ### Step 1 - Review Useful Tools for Bivariate Relationships

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# #### Fill in the blanks below with brief explanations of each type of plot listed
#
# - Categorical Data
# Such variables take on a fixed and limited number of possible values.
# Contingency Table
# >
# crosstabulation/two-way tables displays data from two categorical variables, it shows frequencies for particular combinations of values of two discrete random variable X and Y.
# >
# Clustered Bar Chart
# >
# >In a clustered bar chart each bar represents one combination of the two categorical variables.
#
# - Mixed Data
# Individual Value Plot
# >
# >It shows a dot for the actual value of each observation in a group, making it easy to spot outliers and see distribution spread.
# >
# Strip Plot
# >
# >a graphical data anlysis technique for summarizing a univariate data set.
# The strip plot consists of: Horizontal axis = the value of the response variable; Vertical axis = all values are set to 1.
#
# - Quantitative Data
# Scatter plots
# >
# A scatter plot is a set of points plotted on a horizontal and vertical axes. Scatter plots are important in statistics because they can show the extent of correlation, if any, between the values of observed quantities or variables.

# %% [markdown]
# ### Step 2 - Create Bivariate Plots & Tables

# %% [markdown]
# In the end of Part 2, you began looking at relationships between variables when you created boxplots which visualized the distribution of salary across different categories. In this step, you will make plots and visualizations to begin looking deeper for patterns and relationships between two variables.

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# ### Use the Pandas Crosstab() function to compare categorical variables

# %% [markdown]
# #### crosstab of gender and education

# %%
# use pd.crosstab to count number of managers at each education level, grouped by gender
pd.crosstab(index=df['gender'], columns=df['education'])
# Out:
# education  bachelors degree  high school  masters degree  some college
# gender
# Female                 5468          387            4514          2361
# Male                   5504          394            4465          2346

# %% [markdown]
# ##### Insights:
# More men in the lower levels of education than the women and yet they're paid less.

# %% [markdown]
# ### Strip plot between age and education

# %%
# create strip plot for age and education
plt.figure(figsize=(12,8))

ax = sns.stripplot(y=df['age'], x=df['education'])

# %% [markdown]
# ##### Insights:
#
# It doen't matter how old you are always follow your dreams, you're never too old for school.

# %% [markdown]
# ### Scatterplot for age and salary

# %%
# create scatterplot for age and salary
sns.scatterplot(x=df['age'], y=df['salary'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='salary'>

# %% [markdown]
# ##### Insights:
#
# if you're between age 50-60 you'll have a higher salary

# %% [markdown]
# ### Scatterplot for industry experience and salary

# %%
# create scatterplot for industry experience and salary
sns.scatterplot(x=df['industry_experience'], y=df['salary'])
# Out:
# <AxesSubplot:xlabel='industry_experience', ylabel='salary'>

# %% [markdown]
# ##### Insights:
#
# The more experienced the better the salary

# %% [markdown]
# ### Step 3 - Pick Two More Bivariate Relationships to Visualize

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %%
# create 1st visualization for bivariate relationship of your choice
plt.figure(figsize=(12,8))

ax = sns.stripplot(x=df['gender'], y=df['salary'])

# %%
# create 2nd visualization for bivariate relationship of your choice
plt.figure(figsize=(12,8))

ax = sns.stripplot(y=df['age'], x=df['industry_experience'])

# %% [markdown]
# ## Part 4 - Correlation & Hypothesis Testing

# %% [markdown]
# ### Step 1 - Review Correlation

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# #### Fill in blanks with brief description of the following terms:
#
#
# - **Correlation**
# > The way data relates to each other and what similarities they have
# ***
#
# - **Correlation Coefficient**
# >describes how one variable moves in relation to another. A positive means the two move in the same direction. A negative means they move in opposite directions. A correlation of zero suggests no correlation at all.

# %% [markdown]
# ### Step 2 - Review Hypothesis Testing & P-Value

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# #### Fill in blanks with brief description of the following terms:
#
# - **Hypothesis**
# > Educated guess
#
# - **Null Hypothesis**
# > A null hypothesis is a type of conjecture in statistics that proposes that there is no difference between certain characteristics of a population or data
#
# - **P-Value**
# > the probability that a particular statistical measure, such as the mean or standard deviation, of an assumed probability distribution will be greater than or equal to (or less than or equal to in some instances) observed results.

# %% [markdown]
# ### Step 3 - Use Pearsonr & Spearmanr To Answer Questions About Correlation and P-Values

# %% [markdown]
# <h3 style='color:red;'> First, load 'salary_numeric.csv' - where education has been re-expressed as numeric variables.</h3>

# %%
# load salary_numeric.csv into dataframe where education levels have been re-expressed as numeric
df = pd.read_csv('salary_numeric.csv')

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %%
# import pearson and spearmanr methods from scipy.stats library
from scipy.stats import pearsonr, spearmanr

# %% [markdown]
# ### What is the correlation between salary and education?

# %% [markdown]
# #### Your Hypothesis =
# > higher education, higher salary

# %%
# calculate correlation and pvalue of salary and education with spearmanr method
spearmanr(df['salary'], df['education'])
# Out:
# SpearmanrResult(correlation=0.47719759648149285, pvalue=0.0)

# %% [markdown]
# A positve correlation between education level and salary.

# %% [markdown]
# #### Are these results statistically significant? How do you know?

# %% [markdown]
# Yes, because the pvalue is 0. Anything lower than .05 is considered significant.

# %% [markdown]
# ### What is the correlation between salary and age?

# %% [markdown]
# #### Your Hypothesis
# > I think there is a positive correlation between salary and age

# %%
# calculate correlation and pvalue of salary and age with pearsonr method
pearsonr(df['salary'], df['age'])
# Out:
# (0.6631258539501832, 0.0)

# %% [markdown]
# There is a positive correlation between salary and age.

# %% [markdown]
# #### Are these results statistically significant? How do you know?

# %% [markdown]
# Yes, because the pvalue is 0. Anything lower than .05 is considered significant.

# %% [markdown]
# ### What is the correlation between salary and industry experience?

# %% [markdown]
# #### Your Hypothesis
# > There is a positive correlation between salary and industry experience

# %%
# calculate correlation and pvalue of salary and industry experience with pearsonr method
spearmanr(df['salary'], df['industry_experience'])
# Out:
# SpearmanrResult(correlation=0.5910071254047617, pvalue=0.0)

# %% [markdown]
# There is a positive correlation between salary and industry experience

# %% [markdown]
# #### Are these results statistically significant? How do you know?

# %% [markdown]
# Yes, because the pvalue is 0. Anything lower than .05 is considered significant.

# %% [markdown]
# ### Step 4 - Report Findings

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# ### What was the null hypothesis for the relationships between education and salary, age and salary, and industry experience and salary?

# %% [markdown]
# The Null hypothesis is that there is no relation between them

# %% [markdown]
# ### Can you reject the null hypothesis for any of the relationships you explored above?

# %% [markdown]
# Yes you can because the pvalue is 0 for all of them

# %% [markdown]
# ## Part 5 - Multivariate Analysis

# %% [markdown]
# ### Step 1 - Review Types of Multivariate Analysis

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# #### Fill in the blanks with a brief description of each plot type
#
# - pairplots
# > visualizes given data to find the relationship between them where the variables can be continuous or categorical.
# - paired scatter plots
# > a matrix of scatterplots that lets you understand the pairwise relationship between different variables in a dataset.
# - correlation matrix
# > is a table showing correlation coefficients between variables.
# - heatmap
# > a representation of data in the form of a map or diagram in which data values are represented as colors.

# %% [markdown]
# ### Step 2 - Create Pairplots for Dataset

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# #### pairplot of whole dataframe

# %%
# create pairplot of dataframe
sns.pairplot(df)

# %% [markdown]
# ##### Insights:
#
# [fill in with your observations from the visualization]

# %% [markdown]
# ### Step 3 - Create Other Multivariate Plots

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# ### Correlation matrix

# %%
# use .corr() to create correlation matrix
df.corr()
# Out:
#                           age  education  industry_experience    salary
# age                  1.000000   0.358189             0.842555  0.663126
# education            0.358189   1.000000             0.348966  0.538828
# industry_experience  0.842555   0.348966             1.000000  0.620691
# salary               0.663126   0.538828             0.620691  1.000000

# %% [markdown]
# ### Heatmap of correlation matrix

# %%
# create heatmap visualization of correlation matrix
plt.figure(figsize=(12,8))

ax = sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# ##### Insights:
#
# With a darker the color it's a more distant relationship and a lighter color means they are closely related

# %% [markdown]
# #### Crosstab of average salary grouped by education and industry

# %%
# use pd.crosstab() to calculate mean salary in each industry grouped by education level
pd.crosstab(index=df['industry'], columns=df['education'], values=df['salary'], aggfunc=np.mean).round(0)
# Out:
# education        12       14        16        18
# industry
# business    46727.0  81647.0   97618.0  112037.0
# finance     48132.0  85814.0  102401.0  117568.0
# healthcare  44772.0  80221.0   94149.0  107954.0
# technology  51156.0  92362.0  108436.0  124632.0

# %% [markdown]
# #### Heatmap of crosstab of average salary grouped by education and industry

# %%
# save above result to new variable
heat_crosstab = pd.crosstab(index=df['industry'], columns=df['education'], values=df['salary'], aggfunc=np.mean).round(0)

# %%
# create heatmap with annotated mean salary in each industry and education level
plt.figure(figsize=(16,10))

ax = sns.heatmap(heat_crosstab, annot=True, linewidths=.5, fmt='g', xticklabels=['High School', 'Some College', "Bachelor's Degree", "Master's Degree"])

plt.xlabel("Education Level", fontsize=14)
plt.ylabel("Industry", fontsize=14)

plt.title("Manager Salaries Across Industries by Education Level", fontsize=18);

# %% [markdown]
# ##### Insights:
#
# With a darker the color it's a more distant relationship and a lighter color means they are closely related

# %% [markdown]
# ### Step 4 - Report Findings

# %%
################################### TO DO #########################################
  
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# ###### Along the way throughout this project, you should have been taking notes on insights from your exploratory data analysis. Take some time in a markdown cell below to write a couple paragraphs summarizing any observations, insights, conclusions, or further questions you have based on the exploratory analysis you conducted this week.

# %% [markdown]
# Plots and charts really help you present data in clean easy to ready format. You can see how closely related things are.

# %% [markdown]
# ### Step 5 - Submit Project

# %% [markdown]
# ###### Push to GitHub, record brief code review video, and share links with Tech Lead and SME.
